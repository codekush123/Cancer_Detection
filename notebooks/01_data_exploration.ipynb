# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = os.path.abspath("..")
CSV_PATH = os.path.join(PROJECT_ROOT, "data", "train-metadata.csv")

df = pd.read_csv(CSV_PATH)

# Drop useless column
df = df.drop(columns=["Unnamed: 0"])

df.head()
# Out:
#         isic_id  patient_id  target
# 0  ISIC_2637011  IP_7279968       0
# 1  ISIC_0015719  IP_3075186       0
# 2  ISIC_0052212  IP_2842074       0
# 3  ISIC_0068279  IP_6890425       0
# 4  ISIC_0074268  IP_8723313       0

# %%
df["target"].value_counts().plot(kind="bar", title="Class Distribution")
plt.show()
